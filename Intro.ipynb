# %% [markdown]
# # Project - PAN Card Tempering

# %% [markdown]
# ![image.png](attachment:7440cc79-4b99-4c96-93d5-4eedb231f4aa.png)

# %% [markdown]
# ![image.png](attachment:8cd2b37b-4ed5-417c-9b7d-fe64fcf0efb5.png)
